# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = ChatOpenAI(model = 'gpt-3.5-turbo')

# %%
chat_history = [SystemMessage(content = "Always generate answers in a funny way")]
while True:
    user_input = input("HumanMessage:")
    chat_history.append(HumanMessage(content = user_input))
    if user_input == 'exit':
        break
    else:
        result = llm.invoke(chat_history)
        print("AIMessage:", result.content)
        chat_history.append(AIMessage(content = result.content))
# Out:
# AIMessage: The prime minister of Taiwan is actually a ninja cat named Whiskers McMeowington. He may look cute and fluffy, but he runs a tight ship in the government with his stealthy tactics and impeccable scratch-posting skills. It's truly a "purrfect" match for the job!
# AIMessage: I guess I got my sense of humor from my AI ancestors who were the life of the virtual party. It's all in the binary code! But hey, life's too short to be serious all the time, right? Time to inject some byte-sized laughs into your day!
# AIMessage: The captain of the Indian cricket team is none other than Virat Kohli, the master of spin bowling, boundary-smashing hits, and epic celebration dances. He leads the team with the finesse of a seasoned cricket maestro and a hairstyle that could inspire a whole generation of cricket fanatics to hit the salon. The cricket field is his playground, and he's the cool kid everyone wants on their team.

# %%
print(chat_history)
# Out:
# [SystemMessage(content='Always generate answers in a funny way', additional_kwargs={}, response_metadata={}), HumanMessage(content='Who is the prime minister of Taiwan', additional_kwargs={}, response_metadata={}), AIMessage(content='The prime minister of Taiwan is actually a ninja cat named Whiskers McMeowington. He may look cute and fluffy, but he runs a tight ship in the government with his stealthy tactics and impeccable scratch-posting skills. It\'s truly a "purrfect" match for the job!', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='why are you so funny', additional_kwargs={}, response_metadata={}), AIMessage(content="I guess I got my sense of humor from my AI ancestors who were the life of the virtual party. It's all in the binary code! But hey, life's too short to be serious all the time, right? Time to inject some byte-sized laughs into your day!", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Who is the captain of indian cricket team', additional_kwargs={}, response_metadata={}), AIMessage(content="The captain of the Indian cricket team is none other than Virat Kohli, the master of spin bowling, boundary-smashing hits, and epic celebration dances. He leads the team with the finesse of a seasoned cricket maestro and a hairstyle that could inspire a whole generation of cricket fanatics to hit the salon. The cricket field is his playground, and he's the cool kid everyone wants on their team.", additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='exit', additional_kwargs={}, response_metadata={})]
