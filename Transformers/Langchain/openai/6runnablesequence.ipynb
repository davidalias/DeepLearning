# %%
from langchain_openai import ChatOpenAI
from langchain_core.runnables import RunnableSequence
from dotenv import load_dotenv
load_dotenv()
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate

# %%
llm = ChatOpenAI(model = "gpt-3.5-turbo")

# %%
template = PromptTemplate(template = "What is the advantage of {topic}",
                        input_variables = ['topic'])
parser = StrOutputParser()

# %%
chain = RunnableSequence(template, llm, parser)
result = chain.invoke({'topic': "How globalization influenced the world?"})

# %%
print(result)
# Out:
# One of the main advantages of how globalization has influenced the world is increased interconnectedness and interdependence among nations. This has led to the sharing of ideas, technology, and resources, promoting economic growth and development. Globalization has also resulted in increased cultural exchange and understanding, as people from different parts of the world have more opportunities to connect and learn from each other. Additionally, globalization has led to the expansion of markets and greater access to a variety of goods and services, benefiting consumers and businesses alike. Overall, globalization has the potential to create a more prosperous and harmonious global community.
