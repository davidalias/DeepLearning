# %%
from langchain_text_splitters import CharacterTextSplitter #Text splitter based on character size
from langchain_community.document_loaders import PyPDFLoader

# %%
splitter = CharacterTextSplitter(chunk_size = 200, chunk_overlap = 30, separator='')

# %%
text = """
One of the most important things I didn't understand about the world when I was a child is the degree to which the returns for performance are superlinear.

Teachers and coaches implicitly told us the returns were linear. "You get out," I heard a thousand times, "what you put in." They meant well, but this is rarely true. If your product is only half as good as your competitor's, you don't get half as many customers. You get no customers, and you go out of business.

It's obviously true that the returns for performance are superlinear in business. Some think this is a flaw of capitalism, and that if we changed the rules it would stop being true. But superlinear returns for performance are a feature of the world, not an artifact of rules we've invented. We see the same pattern in fame, power, military victories, knowledge, and even benefit to humanity. In all of these, the rich get richer. [1]

You can't understand the world without understanding the concept of superlinear returns. And if you're ambitious you definitely should, because this will be the wave you surf on.

It may seem as if there are a lot of different situations with superlinear returns, but as far as I can tell they reduce to two fundamental causes: exponential growth and thresholds.

The most obvious case of superlinear returns is when you're working on something that grows exponentially. For example, growing bacterial cultures. When they grow at all, they grow exponentially. But they're tricky to grow. Which means the difference in outcome between someone who's adept at it and someone who's not is very great.

Startups can also grow exponentially, and we see the same pattern there. Some manage to achieve high growth rates. Most don't. And as a result you get qualitatively different outcomes: the companies with high growth rates tend to become immensely valuable, while the ones with lower growth rates may not even survive.

Y Combinator encourages founders to focus on growth rate rather than absolute numbers. It prevents them from being discouraged early on, when the absolute numbers are still low. It also helps them decide what to focus on: you can use growth rate as a compass to tell you how to evolve the company. But the main advantage is that by focusing on growth rate you tend to get something that grows exponentially.

YC doesn't explicitly tell founders that with growth rate "you get out what you put in," but it's not far from the truth. And if growth rate were proportional to performance, then the reward for performance p over time t would be proportional to pt.

Even after decades of thinking about this, I find that sentence startling.
"""

# %%
list_of_chunks = splitter.split_text(text=text)

# %%
print(len(list_of_chunks))
# Out:
# 16

# %%
for chunk in list_of_chunks:
    print(chunk)
    print("----------------------------------")
# Out:
# One of the most important things I didn't understand about the world when I was a child is the degree to which the returns for performance are superlinear.
#
# Teachers and coaches implicitly told us th
# ----------------------------------
# coaches implicitly told us the returns were linear. "You get out," I heard a thousand times, "what you put in." They meant well, but this is rarely true. If your product is only half as good as your
# ----------------------------------
# is only half as good as your competitor's, you don't get half as many customers. You get no customers, and you go out of business.
#
# It's obviously true that the returns for performance are superlinea
# ----------------------------------
# for performance are superlinear in business. Some think this is a flaw of capitalism, and that if we changed the rules it would stop being true. But superlinear returns for performance are a feature o
# ----------------------------------
# or performance are a feature of the world, not an artifact of rules we've invented. We see the same pattern in fame, power, military victories, knowledge, and even benefit to humanity. In all of these
# ----------------------------------
# t to humanity. In all of these, the rich get richer. [1]
#
# You can't understand the world without understanding the concept of superlinear returns. And if you're ambitious you definitely should, becaus
# ----------------------------------
# you definitely should, because this will be the wave you surf on.
#
# It may seem as if there are a lot of different situations with superlinear returns, but as far as I can tell they reduce to two fund
# ----------------------------------
# n tell they reduce to two fundamental causes: exponential growth and thresholds.
#
# The most obvious case of superlinear returns is when you're working on something that grows exponentially. For example
# ----------------------------------
# ows exponentially. For example, growing bacterial cultures. When they grow at all, they grow exponentially. But they're tricky to grow. Which means the difference in outcome between someone who's adep
# ----------------------------------
# ome between someone who's adept at it and someone who's not is very great.
#
# Startups can also grow exponentially, and we see the same pattern there. Some manage to achieve high growth rates. Most don'
# ----------------------------------
# e high growth rates. Most don't. And as a result you get qualitatively different outcomes: the companies with high growth rates tend to become immensely valuable, while the ones with lower growth rate
# ----------------------------------
# he ones with lower growth rates may not even survive.
#
# Y Combinator encourages founders to focus on growth rate rather than absolute numbers. It prevents them from being discouraged early on, when the
# ----------------------------------
# discouraged early on, when the absolute numbers are still low. It also helps them decide what to focus on: you can use growth rate as a compass to tell you how to evolve the company. But the main adva
# ----------------------------------
# the company. But the main advantage is that by focusing on growth rate you tend to get something that grows exponentially.
#
# YC doesn't explicitly tell founders that with growth rate "you get out what
# ----------------------------------
# growth rate "you get out what you put in," but it's not far from the truth. And if growth rate were proportional to performance, then the reward for performance p over time t would be proportional to
# ----------------------------------
# me t would be proportional to pt.
#
# Even after decades of thinking about this, I find that sentence startling.
# ----------------------------------

# %%
loader = PyPDFLoader(file_path='pdfload.pdf')
list_of_docs = loader.load()

# %%
list_of_chunks = splitter.split_documents(list_of_docs)

# %%
print(len(list_of_chunks))
# Out:
# 13

# %%
for chunk in list_of_chunks:
    print(chunk) #every chunk will be a document
    print("--------------------------")
# Out:
# page_content='Here’s a collection of 50 short, clear sentences about AI and psychology:
# 1. AI can analyze human emotions.
# 2. Psychology studies how people think.
# 3. AI models can detect stress in voices.
# 4. Psy' metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-03-16T14:36:09+05:30', 'author': 'Davis Boban', 'moddate': '2026-03-16T14:36:09+05:30', 'source': 'pdfload.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}
# --------------------------
# page_content='tect stress in voices.
# 4. Psychologists explore memory and behavior.
# 5. AI helps in diagnosing mental health issues.
# 6. Psychology explains why people make choices.
# 7. AI can simulate human decisi' metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-03-16T14:36:09+05:30', 'author': 'Davis Boban', 'moddate': '2026-03-16T14:36:09+05:30', 'source': 'pdfload.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}
# --------------------------
# page_content='. AI can simulate human decision-making.
# 8. Psychology investigates learning processes.
# 9. AI chatbots provide emotional support.
# 10. Psychology emphasizes empathy in communication.
# 11. AI can pre' metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-03-16T14:36:09+05:30', 'author': 'Davis Boban', 'moddate': '2026-03-16T14:36:09+05:30', 'source': 'pdfload.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}
# --------------------------
# page_content='communication.
# 11. AI can predict mood changes.
# 12. Psychology studies motivation and goals.
# 13. AI recognizes facial expressions.
# 14. Psychology explores personality traits.
# 15. AI can personali' metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-03-16T14:36:09+05:30', 'author': 'Davis Boban', 'moddate': '2026-03-16T14:36:09+05:30', 'source': 'pdfload.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}
# --------------------------
# page_content='traits.
# 15. AI can personalize therapy sessions.
# 16. Psychology examines social interactions.
# 17. AI uses data to understand habits.
# 18. Psychology explains cognitive biases.
# 19. AI can mimic hu' metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-03-16T14:36:09+05:30', 'author': 'Davis Boban', 'moddate': '2026-03-16T14:36:09+05:30', 'source': 'pdfload.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}
# --------------------------
# page_content='e biases.
# 19. AI can mimic human conversation.
# 20. Psychology studies attention and focus.
# 21. AI supports therapists with insights.
# 22. Psychology explores childhood development.
# 23. AI can trac' metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-03-16T14:36:09+05:30', 'author': 'Davis Boban', 'moddate': '2026-03-16T14:36:09+05:30', 'source': 'pdfload.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}
# --------------------------
# page_content='development.
# 23. AI can track sleep patterns.
# 24. Psychology studies dreams and subconscious.
# 25. AI helps reduce loneliness.' metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-03-16T14:36:09+05:30', 'author': 'Davis Boban', 'moddate': '2026-03-16T14:36:09+05:30', 'source': 'pdfload.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}
# --------------------------
# page_content='26. Psychology explains group behavior.
# 27. AI can measure stress levels.
# 28. Psychology studies resilience.
# 29. AI can adapt to user emotions.
# 30. Psychology explores memory recall.
# 31. AI suppo' metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-03-16T14:36:09+05:30', 'author': 'Davis Boban', 'moddate': '2026-03-16T14:36:09+05:30', 'source': 'pdfload.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}
# --------------------------
# page_content='s memory recall.
# 31. AI supports mental health apps.
# 32. Psychology studies creativity.
# 33. AI can detect depression signals.
# 34. Psychology explains coping strategies.
# 35. AI can recommend relax' metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-03-16T14:36:09+05:30', 'author': 'Davis Boban', 'moddate': '2026-03-16T14:36:09+05:30', 'source': 'pdfload.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}
# --------------------------
# page_content='s.
# 35. AI can recommend relaxation techniques.
# 36. Psychology studies emotional intelligence.
# 37. AI can analyze handwriting for mood.
# 38. Psychology explores decision fatigue.
# 39. AI can persona' metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-03-16T14:36:09+05:30', 'author': 'Davis Boban', 'moddate': '2026-03-16T14:36:09+05:30', 'source': 'pdfload.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}
# --------------------------
# page_content='n fatigue.
# 39. AI can personalize learning paths.
# 40. Psychology studies motivation in education.
# 41. AI can simulate empathy.
# 42. Psychology explains human fears.
# 43. AI can detect anxiety patte' metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-03-16T14:36:09+05:30', 'author': 'Davis Boban', 'moddate': '2026-03-16T14:36:09+05:30', 'source': 'pdfload.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}
# --------------------------
# page_content='3. AI can detect anxiety patterns.
# 44. Psychology studies stress management.
# 45. AI can provide mindfulness reminders.
# 46. Psychology explores self-awareness.
# 47. AI can predict burnout risk.
# 48.' metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-03-16T14:36:09+05:30', 'author': 'Davis Boban', 'moddate': '2026-03-16T14:36:09+05:30', 'source': 'pdfload.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}
# --------------------------
# page_content='can predict burnout risk.
# 48. Psychology studies relationships.
# 49. AI can enhance therapy outcomes.
# 50. Psychology and AI together improve well-being.' metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-03-16T14:36:09+05:30', 'author': 'Davis Boban', 'moddate': '2026-03-16T14:36:09+05:30', 'source': 'pdfload.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}
# --------------------------

# %%
print(list_of_chunks[2])
# Out:
# page_content='. AI can simulate human decision-making.
# 8. Psychology investigates learning processes.
# 9. AI chatbots provide emotional support.
# 10. Psychology emphasizes empathy in communication.
# 11. AI can pre' metadata={'producer': 'Microsoft® Word 2024', 'creator': 'Microsoft® Word 2024', 'creationdate': '2026-03-16T14:36:09+05:30', 'author': 'Davis Boban', 'moddate': '2026-03-16T14:36:09+05:30', 'source': 'pdfload.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}

# %%
print(list_of_chunks[0].page_content)
# Out:
# Here’s a collection of 50 short, clear sentences about AI and psychology:
# 1. AI can analyze human emotions.
# 2. Psychology studies how people think.
# 3. AI models can detect stress in voices.
# 4. Psy
