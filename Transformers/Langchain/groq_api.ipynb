# %%
from dotenv import load_dotenv
load_dotenv()
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model = "openai/gpt-oss-20b")

# %%
result = llm.invoke("Who is the captain of Indian cricket team?")
print(result.content)
# Out:
# **India – Men’s Team**
#
# - **Captain (all formats – Test, ODI, T20I)**: **Rohit Sharma**
#   Rohit Sharma has been the head of the Indian side across all three formats since he was named Test captain in 2022 and continued as ODI/T20I skipper from 2021 onward.
#
# **India – Women’s Team**
#
# - **Captain (all formats – Test, ODI, T20I)**: **Harmanpreet Kaur**
#   Harmanpreet Kaur took over the captaincy from Mithali Raj in late 2022 and has led the women's team in all formats up to 2026.
#
# *(If you were asking about a specific format or a different team, let me know and I can give the most up‑to‑date details.)*
